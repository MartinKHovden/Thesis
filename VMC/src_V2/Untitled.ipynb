# %%
import numpy as np 

densities = np.loadtxt("onebodytest.txt")

# %%
normalized = []
for i in range(len(densities)):
    normalized.append(densities[i]/((2*i+1)*np.pi*((10/1000)**2)))

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,20))
plt.scatter(range(500),normalized[:500], s = 5)
plt.show()

# %%
vmc = np.loadtxt("Data/calogeroSutherland/VMC/Interacting/wf_slater_gaussian_nn_sysInfo_is_stepLength_0.0005_numMCSteps_10000_optimizer_adam_learningRate_0.005_numOptimSteps_8000_numDims_1_numParticles_2_elementinfo_slater_none_gaussian_none_nn_numhidden1_10_numhidden2_1_activationFunction_sigmoid_.txt")

# %%
plt.figure(figsize=(20,20))
plt.plot(vmc)
plt.show()
