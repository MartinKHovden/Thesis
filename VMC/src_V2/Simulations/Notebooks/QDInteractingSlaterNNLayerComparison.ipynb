# %%
import numpy as np
import matplotlib.pyplot as plt
print(np.mean(np.loadtxt("../Test.csv")[:3], axis=0))
print(np.sqrt(np.var(np.loadtxt("../Test.csv")[:3], axis=0)))

plt.figure(figsize=(20,10))
x = [(3.0 - e)/3 for e in [3.01324911, 3.00434, 3.0013492 , 2.99840042, 3.00155]]
variances = [0.00691227, 0.0051, 0.00464762, 0.0032, 0.00242814]
plt.errorbar([5, 10, 15, 20, 25],x, yerr=variances, fmt='o', capsize=7, capthick=3, markersize = 15)
x_tanh = [(3.0 - e)/3 for e in [3.01792121, 3.0101932, 3.00198234, 3.00176322, 3.001823]]
variances_tanh = [0.007219, 0.0033, 0.005124, 0.0034, 0.002523]
plt.errorbar([5,10,15,20,25], x_tanh, yerr= variances_tanh, fmt='o', capsize=7, capthick=3, markersize = 15)
plt.legend(["N = 2"], fontsize=30)
plt.ylabel(r"Relative error: $(E - E_0)/E_0$", fontsize=30)
plt.xlabel("Number of hidden neurons", fontsize=30)
plt.legend(["Sigmoid", "Tanh"], fontsize = 30)
plt.xticks([5, 10, 15, 20, 25], fontsize=30)
plt.yticks(fontsize=30)
plt.axhline(y=0, linestyle='--', c= 'k')

plt.savefig("../Plots/QDInteracting22SlaterNNLayerComparison.png")
# Out:
# [3.01324911 3.0013492  2.99640042]
# [0.00691227 0.00464762 0.00242814]

# %%
x = np.loadtxt("../Test.csv")
print(x)

np.sqrt(np.var([3.00068608, 3.00734387, 2.99601765, 2.99901765 , 2.9990176]))
# Out:
# [[3.02014656 3.00068608 2.9975165 ]
#  [3.0157994  3.00734387 2.99302997]
#  [3.00380137 2.99601765 2.99865477]
#  [0.         0.         0.        ]
#  [0.         0.         0.        ]]
# 0.0037768958768756135
