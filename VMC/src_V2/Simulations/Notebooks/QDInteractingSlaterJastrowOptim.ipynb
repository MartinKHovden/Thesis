# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
lr0_1 = np.loadtxt("../Data/quantumDot/VMC/Interacting/wf_slater_gaussian_padeJastrow_sysInfo_is_stepLength_0.05_numMCSteps_10000_optimizer_adam_learningRate_0.1_numOptimSteps_500_numDims_2_numParticles_2_elementinfo_slater_none_gaussian_none_padeJastrow_none_.txt")
lr0_01 = np.loadtxt("../Data/quantumDot/VMC/Interacting/wf_slater_gaussian_padeJastrow_sysInfo_is_stepLength_0.05_numMCSteps_10000_optimizer_adam_learningRate_0.01_numOptimSteps_500_numDims_2_numParticles_2_elementinfo_slater_none_gaussian_none_padeJastrow_none_.txt")
lr0_001 = np.loadtxt("../Data/quantumDot/VMC/Interacting/wf_slater_gaussian_padeJastrow_sysInfo_is_stepLength_0.05_numMCSteps_10000_optimizer_adam_learningRate_0.001_numOptimSteps_500_numDims_2_numParticles_2_elementinfo_slater_none_gaussian_none_padeJastrow_none_.txt")

plt.figure(figsize=(20,10))

plt.plot(lr0_001, linewidth=3)
plt.plot(lr0_01, linewidth=3)
plt.plot(lr0_1, linewidth=3)
plt.legend(["lr = 0.001", "lr=0.01", "lr=0.1"], fontsize=25)
plt.xlabel("Iteration", fontsize=30)
plt.ylabel("Energy", fontsize=30)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
plt.savefig("../Plots/Interacting22SlaterJastrowOptimADAM.png")

# %%
lr0_1 = np.loadtxt("../Data/quantumDot/VMC/Interacting/wf_slater_gaussian_padeJastrow_sysInfo_is_stepLength_0.05_numMCSteps_100000_optimizer_adam_learningRate_0.1_numOptimSteps_100_numDims_2_numParticles_2_elementinfo_slater_none_gaussian_none_padeJastrow_none_.txt")
lr0_01 = np.loadtxt("../Data/quantumDot/VMC/Interacting/wf_slater_gaussian_padeJastrow_sysInfo_is_stepLength_0.05_numMCSteps_100000_optimizer_adam_learningRate_0.01_numOptimSteps_100_numDims_2_numParticles_2_elementinfo_slater_none_gaussian_none_padeJastrow_none_.txt")

plt.figure(figsize=(20,10))

plt.plot(lr0_01, linewidth=3)
plt.plot(lr0_1, linewidth=3)
plt.legend(["lr = 0.001", "lr=0.01", "lr=0.1"], fontsize=25)
plt.xlabel("Iteration", fontsize=30)
plt.ylabel("Energy", fontsize=30)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
plt.savefig("../Plots/Interacting22SlaterJastrowOptimADAM.png")
