# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
lr1 = np.loadtxt("../Data/quantumDot/VMC/Non_Interacting/wf_slater_gaussian_sysInfo_is_stepLength_0.5_numMCSteps_10000_optimizer_gd_learningRate_1.0_numOptimSteps_1000_numDims_2_numParticles_2_elementinfo_slater_none_gaussian_none_.txt")
lr0_1 = np.loadtxt("../Data/quantumDot/VMC/Non_Interacting/wf_slater_gaussian_sysInfo_is_stepLength_0.5_numMCSteps_10000_optimizer_gd_learningRate_0.1_numOptimSteps_1000_numDims_2_numParticles_2_elementinfo_slater_none_gaussian_none_.txt")
lr0_01 = np.loadtxt("../Data/quantumDot/VMC/Non_Interacting/wf_slater_gaussian_sysInfo_is_stepLength_0.5_numMCSteps_10000_optimizer_gd_learningRate_0.01_numOptimSteps_1000_numDims_2_numParticles_2_elementinfo_slater_none_gaussian_none_.txt")
lr0_001 = np.loadtxt("../Data/quantumDot/VMC/Non_Interacting/wf_slater_gaussian_sysInfo_is_stepLength_0.5_numMCSteps_10000_optimizer_gd_learningRate_0.001_numOptimSteps_1000_numDims_2_numParticles_2_elementinfo_slater_none_gaussian_none_.txt")

# %%
plt.figure(figsize=(20,10))

plt.plot(lr0_001)
plt.plot(lr0_01)
plt.plot(lr0_1)
plt.plot(lr1)
plt.legend(["lr = 0.001", "lr=0.01", "lr=0.1", "lr=1.0"])
plt.ylim((2.0, 2.01))
# Out:
# (2.0, 2.01)

# %%
lr1 = np.loadtxt("../Data/quantumDot/VMC/Non_Interacting/wf_slater_gaussian_sysInfo_is_stepLength_0.5_numMCSteps_100000_optimizer_gd_learningRate_1.0_numOptimSteps_500_numDims_2_numParticles_2_elementinfo_slater_none_gaussian_none_.txt")
lr0_1 = np.loadtxt("../Data/quantumDot/VMC/Non_Interacting/wf_slater_gaussian_sysInfo_is_stepLength_0.5_numMCSteps_100000_optimizer_gd_learningRate_0.1_numOptimSteps_500_numDims_2_numParticles_2_elementinfo_slater_none_gaussian_none_.txt")
lr0_01 = np.loadtxt("../Data/quantumDot/VMC/Non_Interacting/wf_slater_gaussian_sysInfo_is_stepLength_0.5_numMCSteps_100000_optimizer_gd_learningRate_0.01_numOptimSteps_500_numDims_2_numParticles_2_elementinfo_slater_none_gaussian_none_.txt")
lr0_001 = np.loadtxt("../Data/quantumDot/VMC/Non_Interacting/wf_slater_gaussian_sysInfo_is_stepLength_0.5_numMCSteps_100000_optimizer_gd_learningRate_0.001_numOptimSteps_500_numDims_2_numParticles_2_elementinfo_slater_none_gaussian_none_.txt")

plt.figure(figsize=(20,10))

plt.plot(lr0_001, linewidth=3)
plt.plot(lr0_01, linewidth=3)
plt.plot(lr0_1, linewidth=3)
plt.plot(lr1, linewidth=3)
plt.legend(["lr = 0.001", "lr=0.01", "lr=0.1", "lr=1.0"], fontsize=25)
plt.xlabel("Iteration", fontsize=30)
plt.ylabel("Energy", fontsize=30)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
plt.savefig("../Plots/QDNonInteracting22SlaterOptimGD.png")

# %%
lr1 = np.loadtxt("../Data/quantumDot/VMC/Non_Interacting/wf_slater_gaussian_sysInfo_is_stepLength_0.5_numMCSteps_100000_optimizer_gd_learningRate_1.0_numOptimSteps_500_numDims_2_numParticles_2_elementinfo_slater_none_gaussian_none_.txt")
lr0_1 = np.loadtxt("../Data/quantumDot/VMC/Non_Interacting/wf_slater_gaussian_sysInfo_is_stepLength_0.5_numMCSteps_100000_optimizer_gd_learningRate_0.1_numOptimSteps_500_numDims_2_numParticles_2_elementinfo_slater_none_gaussian_none_.txt")
lr0_01 = np.loadtxt("../Data/quantumDot/VMC/Non_Interacting/wf_slater_gaussian_sysInfo_is_stepLength_0.5_numMCSteps_100000_optimizer_gd_learningRate_0.01_numOptimSteps_500_numDims_2_numParticles_2_elementinfo_slater_none_gaussian_none_.txt")
lr0_001 = np.loadtxt("../Data/quantumDot/VMC/Non_Interacting/wf_slater_gaussian_sysInfo_is_stepLength_0.5_numMCSteps_100000_optimizer_gd_learningRate_0.001_numOptimSteps_500_numDims_2_numParticles_2_elementinfo_slater_none_gaussian_none_.txt")

fig,ax = plt.subplots(2,1, figsize=(20,10))



ax[0].plot(lr0_001, linewidth=3)
ax[0].plot(lr0_01, linewidth=3)
ax[0].plot(lr0_1, linewidth=3)
ax[0].plot(lr1, linewidth=3)
ax[0].legend(["lr = 0.001", "lr=0.01", "lr=0.1", "lr=1.0"], fontsize=25)
ax[0].set_ylim((2.0, 2.0125))
ax[0].tick_params(labelsize=25)
ax[0].set_ylabel("Energy", fontsize=30)
ax[0].yaxis.offsetText.set_fontsize(25)



ax[1].plot([abs(2.0 - e) for e in lr0_001], linewidth=3)
ax[1].plot([abs(2.0 - e) for e in lr0_01], linewidth=3)
ax[1].plot([abs(2.0 - e) for e in lr0_1], linewidth=3)
ax[1].plot([abs(2.0 - e) for e in lr1], linewidth=3)
ax[1].set_yscale("log")

# ax[1].plot(np.linspace(0,5,len(normalizedSlater)),normalizedNN, "--")

ax[1].legend(["lr = 0.001", "lr=0.01", "lr=0.1", "lr=1.0"], fontsize=25)

ax[1].tick_params(labelsize=25)
ax[1].set_xlabel("Iteration", fontsize=30)
ax[1].set_ylabel("Error", fontsize=30)

ax[1].yaxis.offsetText.set_fontsize(25)

plt.savefig("../Plots/QDNonInteracting22SlaterOptimGD.png")

# %%
lr1 = np.loadtxt("../Data/quantumDot/VMC/Non_Interacting/wf_slater_gaussian_sysInfo_is_stepLength_0.5_numMCSteps_100000_optimizer_adam_learningRate_1.0_numOptimSteps_500_numDims_2_numParticles_2_elementinfo_slater_none_gaussian_none_.txt")
lr0_1 = np.loadtxt("../Data/quantumDot/VMC/Non_Interacting/wf_slater_gaussian_sysInfo_is_stepLength_0.5_numMCSteps_100000_optimizer_adam_learningRate_0.1_numOptimSteps_500_numDims_2_numParticles_2_elementinfo_slater_none_gaussian_none_.txt")
lr0_01 = np.loadtxt("../Data/quantumDot/VMC/Non_Interacting/wf_slater_gaussian_sysInfo_is_stepLength_0.5_numMCSteps_100000_optimizer_adam_learningRate_0.01_numOptimSteps_500_numDims_2_numParticles_2_elementinfo_slater_none_gaussian_none_.txt")
lr0_001 = np.loadtxt("../Data/quantumDot/VMC/Non_Interacting/wf_slater_gaussian_sysInfo_is_stepLength_0.5_numMCSteps_100000_optimizer_adam_learningRate_0.001_numOptimSteps_500_numDims_2_numParticles_2_elementinfo_slater_none_gaussian_none_.txt")

plt.figure(figsize=(20,10))

plt.plot(lr0_001, linewidth=3)
plt.plot(lr0_01, linewidth=3)
plt.plot(lr0_1, linewidth=3)
plt.plot(lr1, linewidth=3)
plt.legend(["lr = 0.001", "lr=0.01", "lr=0.1", "lr=1.0"], fontsize=25)
plt.xlabel("Iteration", fontsize=30)
plt.ylabel("Energy", fontsize=30)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
plt.ylim((2.0, 2.01))
plt.savefig("../Plots/QDNonInteracting22SlaterOptimADAM.png")

# %%
lr1 = np.loadtxt("../Data/quantumDot/VMC/Non_Interacting/wf_slater_gaussian_sysInfo_is_stepLength_0.5_numMCSteps_100000_optimizer_adam_learningRate_1.0_numOptimSteps_500_numDims_2_numParticles_2_elementinfo_slater_none_gaussian_none_.txt")
lr0_1 = np.loadtxt("../Data/quantumDot/VMC/Non_Interacting/wf_slater_gaussian_sysInfo_is_stepLength_0.5_numMCSteps_100000_optimizer_adam_learningRate_0.1_numOptimSteps_500_numDims_2_numParticles_2_elementinfo_slater_none_gaussian_none_.txt")
lr0_01 = np.loadtxt("../Data/quantumDot/VMC/Non_Interacting/wf_slater_gaussian_sysInfo_is_stepLength_0.5_numMCSteps_100000_optimizer_adam_learningRate_0.01_numOptimSteps_500_numDims_2_numParticles_2_elementinfo_slater_none_gaussian_none_.txt")
lr0_001 = np.loadtxt("../Data/quantumDot/VMC/Non_Interacting/wf_slater_gaussian_sysInfo_is_stepLength_0.5_numMCSteps_100000_optimizer_adam_learningRate_0.001_numOptimSteps_500_numDims_2_numParticles_2_elementinfo_slater_none_gaussian_none_.txt")


fig,ax = plt.subplots(2,1, figsize=(20,10))



ax[0].plot(lr0_001, linewidth=3)
ax[0].plot(lr0_01, linewidth=3)
ax[0].plot(lr0_1, linewidth=3)
ax[0].plot(lr1, linewidth=3)
ax[0].legend(["lr = 0.001", "lr=0.01", "lr=0.1", "lr=1.0"], fontsize=25)
ax[0].set_ylim((2.0, 2.0125))
ax[0].tick_params(labelsize=25)
ax[0].set_ylabel("Energy", fontsize=30)
ax[0].yaxis.offsetText.set_fontsize(25)



ax[1].plot([abs(2.0 - e) for e in lr0_001], linewidth=3)
ax[1].plot([abs(2.0 - e) for e in lr0_01], linewidth=3)
ax[1].plot([abs(2.0 - e) for e in lr0_1], linewidth=3)
ax[1].plot([abs(2.0 - e) for e in lr1], linewidth=3)
ax[1].set_yscale("log")

# ax[1].plot(np.linspace(0,5,len(normalizedSlater)),normalizedNN, "--")

ax[1].legend(["lr = 0.001", "lr=0.01", "lr=0.1", "lr=1.0"], fontsize=25)

ax[1].tick_params(labelsize=25)
ax[1].set_xlabel("Iteration", fontsize=30)
ax[1].set_ylabel("Error", fontsize=30)

ax[1].yaxis.offsetText.set_fontsize(25)

plt.savefig("../Plots/QDNonInteracting22SlaterOptimADAM.png")
