# %%
import numpy as np
import matplotlib.pyplot as plt  

densitiesSlaterNN = np.loadtxt("../Data/quantumDot/OneBody/onebodyInteracting22SlaterNN.txt")
densitiesSlaterNN = [sum(densitiesSlaterNN[i:i+3]) for i in range(0, len(densitiesSlaterNN), 3)]


normalizationFactor = 2.0
normalizedSlaterNN = []
for i in range(len(densities)):
    normalizedSlaterNN.append(densities[i]/((2*i+1)*np.pi*((5*3/2000)**2)))


# densities = np.loadtxt("../Data/quantumDot/OneBody/onebodytest.txt")

# normalizationFactor = 2.0
# normalizedNN = []
# for i in range(len(densities)):
#     normalizedNN.append(densities[i]/((2*i+1)*np.pi*((5/2000)**2)))

fig,ax = plt.subplots(figsize=(20,10))


ax.scatter(np.linspace(0,5,len(normalizedSlaterNN)),normalizedSlaterNN, s = 60)
# ax[0].plot(np.linspace(0,5,len(normalizedSlater)),[np.exp(-r**2)*1.32e6 for r in np.linspace(0,5,len(normalizedSlater))], '--ro' , markersize=1)
ax.legend([ "VMC: Slater-NN","VMC: Slater"], fontsize=25)
# ax.set_ylim(0,125000)
ax.tick_params(labelsize=25)
ax.set_xlabel("r", fontsize=30)
ax.yaxis.offsetText.set_fontsize(25)

# %%
import numpy as np
import matplotlib.pyplot as plt  

densitiesSlaterJastrow = np.loadtxt("../Data/quantumDot/OneBody/onebodytest.txt")
densitiesSlaterJastrow = [sum(densitiesSlaterJastrow[i:i+3]) for i in range(0, len(densitiesSlaterJastrow), 3)]


normalizationFactor = 2.0
normalizedSlaterJastrow = []
for i in range(len(densitiesSlaterJastrow)):
    normalizedSlaterJastrow.append(densitiesSlaterJastrow[i]/((2*i+1)*np.pi*((5*3/2000)**2)))


# densities = np.loadtxt("../Data/quantumDot/OneBody/onebodytest.txt")

# normalizationFactor = 2.0
# normalizedNN = []
# for i in range(len(densities)):
#     normalizedNN.append(densities[i]/((2*i+1)*np.pi*((5/2000)**2)))

fig,ax = plt.subplots(figsize=(20,10))


ax.scatter(np.linspace(0,5,len(normalizedSlaterJastrow)),normalizedSlaterJastrow, s = 60)
# ax[0].plot(np.linspace(0,5,len(normalizedSlater)),[np.exp(-r**2)*1.32e6 for r in np.linspace(0,5,len(normalizedSlater))], '--ro' , markersize=1)
ax.legend([ "VMC: Slater-NN","VMC: Slater"], fontsize=25)
# ax.set_ylim(0,1250000)
ax.tick_params(labelsize=25)
ax.set_xlabel("r", fontsize=30)
ax.yaxis.offsetText.set_fontsize(25)

# %%
import numpy as np
import matplotlib.pyplot as plt  

densities = np.loadtxt("../Data/quantumDot/OneBody/onebodyInteracting22SlaterJastrow.txt")
densities = [sum(densities[i:i+3]) for i in range(0, len(densities), 3)]


normalizedSlaterJastrow = []
for i in range(len(densities)):
    normalizedSlaterJastrow.append(1.01*densities[i]/((2*i+1)*np.pi*((5*3/2000)**2)))


densities = np.loadtxt("../Data/quantumDot/OneBody/onebodyInteracting22SlaterNN.txt")
densities = [sum(densities[i:i+3]) for i in range(0, len(densities), 3)]


normalizedSlaterNN = []
for i in range(len(densities)):
    normalizedSlaterNN.append(densities[i]/((2*i+1)*np.pi*((5*3/2000)**2)))


# densities = np.loadtxt("../Data/quantumDot/OneBody/onebodytest.txt")

# normalizationFactor = 2.0
# normalizedNN = []
# for i in range(len(densities)):
#     normalizedNN.append(densities[i]/((2*i+1)*np.pi*((5/2000)**2)))

fig,ax = plt.subplots(figsize=(20,10))

ax.scatter(np.linspace(0,5,len(normalizedSlaterNN)),normalizedSlaterNN, s = 60)
ax.scatter(np.linspace(0,5,len(normalizedSlaterJastrow)),normalizedSlaterJastrow, s = 60)
# ax[0].plot(np.linspace(0,5,len(normalizedSlater)),[np.exp(-r**2)*1.32e6 for r in np.linspace(0,5,len(normalizedSlater))], '--ro' , markersize=1)
ax.legend([ "VMC: Slater-NN","VMC: Slater-Jastrow"], fontsize=25)
# ax.set_ylim(0,1250000)
ax.tick_params(labelsize=25)
ax.set_xlabel("r", fontsize=30)
ax.yaxis.offsetText.set_fontsize(25)

plt.savefig("../Plots/QDInteracting22OnebodyComparison.png")

# %%
import numpy as np
import matplotlib.pyplot as plt  

densities = np.loadtxt("../Data/quantumDot/OneBody/onebodytest.txt")
densities = [sum(densities[i:i+3]) for i in range(0, len(densities), 3)]


normalizedSlaterJastrow = []
for i in range(len(densities)):
    normalizedSlaterJastrow.append(densities[i]/((2*i+1)*np.pi*((10*3/4000)**2)))


densities = np.loadtxt("../Data/quantumDot/OneBody/onebodyInteracting62SlaterNN2.txt")
densities = [sum(densities[i:i+3]) for i in range(0, len(densities), 3)]


normalizedSlaterNN = []
for i in range(len(densities)):
    normalizedSlaterNN.append(0.97*densities[i]/((2*i+1)*np.pi*((10*3/4000)**2)))

# normalizeSlaterNN = np.concatenate(normalizedSlaterNN, np.zeros(2000))

# densities = np.loadtxt("../Data/quantumDot/OneBody/onebodytest.txt")

# normalizationFactor = 2.0
# normalizedNN = []
# for i in range(len(densities)):
#     normalizedNN.append(densities[i]/((2*i+1)*np.pi*((5/2000)**2)))

fig,ax = plt.subplots(figsize=(20,10))

ax.scatter(np.linspace(0,10,len(normalizedSlaterNN)),normalizedSlaterNN, s = 60)
ax.scatter(np.linspace(0,10,len(normalizedSlaterJastrow)),normalizedSlaterJastrow, s = 60)
# ax[0].plot(np.linspace(0,5,len(normalizedSlater)),[np.exp(-r**2)*1.32e6 for r in np.linspace(0,5,len(normalizedSlater))], '--ro' , markersize=1)
ax.legend([ "VMC: Slater-NN","VMC: Slater-Jastrow"], fontsize=25)
# ax.set_ylim(0,3250000)
ax.tick_params(labelsize=25)
ax.set_xlabel("r", fontsize=30)
ax.yaxis.offsetText.set_fontsize(25)

plt.savefig("../Plots/QDInteracting62OnebodyComparison.png")
