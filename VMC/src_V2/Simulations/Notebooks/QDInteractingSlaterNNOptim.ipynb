# %%
import numpy as np 
import matplotlib.pyplot as plt

x = np.loadtxt("../Data/quantumDot/VMC/Interacting/wf_slater_gaussian_nn_sysInfo_is_stepLength_0.1_numMCSteps_1000_optimizer_adam_learningRate_0.01_numOptimSteps_1000_numDims_2_numParticles_2_elementinfo_slater_none_gaussian_none_nn_numhidden1_15_numhidden2_15_activationFunction_sigmoid_.txt")

# %%
plt.plot([(3.0-e)/3.0 for e in np.mean((x.reshape(-1, 5)), axis=1)])
# plt.ylim(-0.04, 0.04)

# %%
import matplotlib.pyplot as plt
lr0_1 = np.loadtxt("../Data/quantumDot/VMC/Interacting/wf_slater_gaussian_nn_sysInfo_is_stepLength_0.1_numMCSteps_1000_optimizer_adam_learningRate_0.1_numOptimSteps_5000_numDims_2_numParticles_2_elementinfo_slater_none_gaussian_none_nn_numhidden1_20_numhidden2_20_activationFunction_sigmoid_.txt")
lr0_01 = np.loadtxt("../Data/quantumDot/VMC/Interacting/wf_slater_gaussian_nn_sysInfo_is_stepLength_0.1_numMCSteps_1000_optimizer_adam_learningRate_0.01_numOptimSteps_5000_numDims_2_numParticles_2_elementinfo_slater_none_gaussian_none_nn_numhidden1_20_numhidden2_20_activationFunction_sigmoid_.txt")
lr0_001 = np.loadtxt("../Data/quantumDot/VMC/Interacting/wf_slater_gaussian_nn_sysInfo_is_stepLength_0.1_numMCSteps_1000_optimizer_adam_learningRate_0.001_numOptimSteps_5000_numDims_2_numParticles_2_elementinfo_slater_none_gaussian_none_nn_numhidden1_20_numhidden2_20_activationFunction_sigmoid_.txt")


# plt.figure(figsize=(20,10))

fig,ax = plt.subplots(2,1, figsize=(20,10))
# plt.plot(lr0_001, linewidth=3)
# plt.plot(lr0_01, linewidth=3)
ax[0].plot([e for e in np.mean((lr0_1.reshape(-1, 10)), axis=1)], linewidth=3)
ax[0].plot([e for e in np.mean((lr0_01.reshape(-1, 10)), axis=1)], linewidth=3)
ax[0].plot([e for e in np.mean((lr0_001.reshape(-1, 10)), axis=1)], linewidth=3)
ax[0].set_ylim(2.6, 3.4)

ax[0].legend(["lr = 0.1", "lr=0.01", "lr=0.001"], fontsize=25)
ax[0].set_ylabel("Energy", fontsize=30)
ax[0].tick_params(labelsize=20)

ax[1].plot([abs(3.0 - e)/3 for e in np.mean((lr0_1.reshape(-1, 10)), axis=1)], linewidth=3)
ax[1].plot([abs(3.0 - e)/3 for e in np.mean((lr0_01.reshape(-1, 10)), axis=1)], linewidth=3)
ax[1].plot([abs(3.0 - e)/3 for e in np.mean((lr0_001.reshape(-1, 10)), axis=1)], linewidth=3)


ax[1].legend(["lr = 0.1", "lr=0.01", "lr=0.001"], fontsize=25)
ax[1].set_xlabel("Iteration", fontsize=30)
ax[1].set_ylabel(r"abs$(E_0 - E)/E_0$", fontsize=30)
ax[1].set_yscale('log')
ax[1].tick_params(labelsize=20)
# plt.show()
plt.savefig("../Plots/QDInteracting22SlaterNNOptimADAM.png")

# %%
import numpy as np 
import matplotlib.pyplot as plt
lr0_05 = np.loadtxt("../Data/quantumDot/VMC/Interacting/wf_slater_gaussian_nn_sysInfo_is_stepLength_0.05_numMCSteps_2000_optimizer_adam_learningRate_0.01_numOptimSteps_2000_numDims_2_numParticles_6_elementinfo_slater_none_gaussian_none_nn_numhidden1_40_numhidden2_40_activationFunction_sigmoid_.txt")
lr0_005 = np.loadtxt("../Data/quantumDot/VMC/Interacting/wf_slater_gaussian_nn_sysInfo_is_stepLength_0.005_numMCSteps_2000_optimizer_adam_learningRate_0.01_numOptimSteps_2000_numDims_2_numParticles_6_elementinfo_slater_none_gaussian_none_nn_numhidden1_40_numhidden2_40_activationFunction_sigmoid_.txt")
lr0_0005 = np.loadtxt("../Data/quantumDot/VMC/Interacting/wf_slater_gaussian_nn_sysInfo_is_stepLength_0.0005_numMCSteps_2000_optimizer_adam_learningRate_0.01_numOptimSteps_2000_numDims_2_numParticles_6_elementinfo_slater_none_gaussian_none_nn_numhidden1_40_numhidden2_40_activationFunction_sigmoid_.txt")
lr0_00005 = np.loadtxt("../Data/quantumDot/VMC/Interacting/wf_slater_gaussian_nn_sysInfo_is_stepLength_5.0e-5_numMCSteps_2000_optimizer_adam_learningRate_0.01_numOptimSteps_2000_numDims_2_numParticles_6_elementinfo_slater_none_gaussian_none_nn_numhidden1_40_numhidden2_40_activationFunction_sigmoid_.txt")


# plt.figure(figsize=(20,10))

fig,ax = plt.subplots(2,1, figsize=(20,10))
# plt.plot(lr0_001, linewidth=3)
# plt.plot(lr0_01, linewidth=3)
reshape = 1
ax[0].plot([e for e in np.mean((lr0_05.reshape(-1, reshape)), axis=1)], linewidth=3)
# ax[0].plot([e for e in np.mean((lr0_005.reshape(-1, reshape)), axis=1)], linewidth=3)
# ax[0].plot([e for e in np.mean((lr0_0005.reshape(-1, reshape)), axis=1)], linewidth=3)
# ax[0].plot([e for e in np.mean((lr0_00005.reshape(-1, reshape)), axis=1)], linewidth=3)
ax[0].set_ylim(20.07, 20.14)

ax[0].legend(["lr = 0.1", "lr=0.01", "lr=0.001"], fontsize=25)
ax[0].set_ylabel("Energy", fontsize=30)
ax[0].tick_params(labelsize=20)

ax[1].plot([abs(20.159 - e)/20.159 for e in np.mean((lr0_05.reshape(-1, reshape)), axis=1)], linewidth=3)
# ax[1].plot([abs(20.159 - e)/20.159 for e in np.mean((lr0_005.reshape(-1, reshape)), axis=1)], linewidth=3)
# ax[1].plot([abs(20.159 - e)/20.159 for e in np.mean((lr0_0005.reshape(-1, reshape)), axis=1)], linewidth=3)
# ax[1].plot([abs(20.159 - e)/20.159 for e in np.mean((lr0_00005.reshape(-1, reshape)), axis=1)], linewidth=3)


ax[1].legend(["lr = 0.1", "lr=0.01", "lr=0.001"], fontsize=25)
ax[1].set_xlabel("Iteration", fontsize=30)
ax[1].set_ylabel(r"abs$(E_0 - E)/E_0$", fontsize=30)
ax[1].set_yscale('log')
ax[1].tick_params(labelsize=20)

# %%
x = np.loadtxt("../Data/quantumDot/VMC/Interacting/wf_slater_gaussian_nn_sysInfo_is_stepLength_0.0005_numMCSteps_2000_optimizer_adam_learningRate_0.01_numOptimSteps_2000_numDims_2_numParticles_6_elementinfo_slater_none_gaussian_none_nn_numhidden1_40_numhidden2_40_activationFunction_sigmoid_.txt")
y = np.loadtxt("../Data/quantumDot/VMC/Interacting/wf_slater_gaussian_nn_sysInfo_is_stepLength_5.0e-5_numMCSteps_2000_optimizer_adam_learningRate_0.01_numOptimSteps_2000_numDims_2_numParticles_6_elementinfo_slater_none_gaussian_none_nn_numhidden1_40_numhidden2_40_activationFunction_sigmoid_.txt")

# %%
fig,ax = plt.subplots(2,1, figsize=(20,10))
# plt.plot(lr0_001, linewidth=3)
# plt.plot(lr0_01, linewidth=3)
reshape = 1
ax[0].plot([e for e in np.mean((x.reshape(-1, reshape)), axis=1)], linewidth=3)
ax[0].plot([e for e in np.mean((y.reshape(-1, reshape)), axis=1)], linewidth=3)
ax[0].set_ylim(15.0, 40.0)

ax[0].legend(["lr = 0.1", "lr=0.01", "lr=0.001"], fontsize=25)
ax[0].set_ylabel("Energy", fontsize=30)
ax[0].tick_params(labelsize=20)

ax[1].plot([abs(20.159 - e)/20.159 for e in np.mean((x.reshape(-1, reshape)), axis=1)], linewidth=3)
ax[1].plot([abs(20.159 - e)/20.159 for e in np.mean((y.reshape(-1, reshape)), axis=1)], linewidth=3)


ax[1].legend(["lr = 0.01", "lr=0.01", "lr=0.001"], fontsize=25)
ax[1].set_xlabel("Iteration", fontsize=30)
ax[1].set_ylabel(r"abs$(E_0 - E)/E_0$", fontsize=30)
ax[1].set_yscale('log')
ax[1].tick_params(labelsize=20)

plt.savefig("../Plots/QDInteracting62SlaterNNOptim.png")

# %%
z = np.loadtxt("../Data/quantumDot/VMC/Interacting/wf_slater_gaussian_nn_sysInfo_is_stepLength_0.0005_numMCSteps_10000_optimizer_adam_learningRate_0.01_numOptimSteps_500_numDims_2_numParticles_6_elementinfo_slater_none_gaussian_none_nn_numhidden1_40_numhidden2_40_activationFunction_sigmoid_.txt")

# %%
fig,ax = plt.subplots(2,1, figsize=(20,10))
# plt.plot(lr0_001, linewidth=3)
# plt.plot(lr0_01, linewidth=3)
reshape = 1
ax[0].plot([e for e in np.mean((z.reshape(-1, reshape)), axis=1)], linewidth=3)
# ax[0].plot([e for e in np.mean((y.reshape(-1, reshape)), axis=1)], linewidth=3)
ax[0].set_ylim(15.0, 40.0)

ax[0].legend(["lr = 0.1", "lr=0.01", "lr=0.001"], fontsize=25)
ax[0].set_ylabel("Energy", fontsize=30)
ax[0].tick_params(labelsize=20)

ax[1].plot([abs(20.159 - e)/20.159 for e in np.mean((z.reshape(-1, reshape)), axis=1)], linewidth=3)
# ax[1].plot([abs(20.159 - e)/20.159 for e in np.mean((y.reshape(-1, reshape)), axis=1)], linewidth=3)


ax[1].legend(["lr = 0.01", "lr=0.01", "lr=0.001"], fontsize=25)
ax[1].set_xlabel("Iteration", fontsize=30)
ax[1].set_ylabel(r"abs$(E_0 - E)/E_0$", fontsize=30)
ax[1].set_yscale('log')
ax[1].tick_params(labelsize=20)
