# %% [markdown]
# # Calogero-Sutherland for interacting particles

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt('../Data/calogeroSutherland/MC/Interacting/wf_slater_gaussian_nn_sysInfo_bf_stepLength_500.0_numMCSteps_10000_numDims_1_numParticles_2_elementinfo_slater_none_gaussian_none_nn_numhidden1_10_numhidden2_1_activationFunction_sigmoid_.txt')
plt.plot(data)

# %%
data = np.loadtxt('../Data/calogeroSutherland/MC/Interacting/wf_slater_gaussian_nn_sysInfo_bf_stepLength_50.0_numMCSteps_10000_numDims_1_numParticles_2_elementinfo_slater_none_gaussian_none_nn_numhidden1_10_numhidden2_1_activationFunction_sigmoid_.txt')
plt.plot(data)

# %%
data = np.loadtxt('../Data/calogeroSutherland/MC/Interacting/wf_slater_gaussian_nn_sysInfo_bf_stepLength_5.0_numMCSteps_10000_numDims_1_numParticles_2_elementinfo_slater_none_gaussian_none_nn_numhidden1_10_numhidden2_1_activationFunction_sigmoid_.txt')
plt.plot(data)

# %%
data = np.loadtxt('../Data/calogeroSutherland/MC/Interacting/wf_slater_gaussian_nn_sysInfo_bf_stepLength_0.5_numMCSteps_10000_numDims_1_numParticles_2_elementinfo_slater_none_gaussian_none_nn_numhidden1_10_numhidden2_1_activationFunction_sigmoid_.txt')
plt.plot(data)

# %%
data = np.loadtxt('../Data/calogeroSutherland/MC/Interacting/wf_slater_gaussian_nn_sysInfo_bf_stepLength_0.05_numMCSteps_10000_numDims_1_numParticles_2_elementinfo_slater_none_gaussian_none_nn_numhidden1_10_numhidden2_1_activationFunction_sigmoid_.txt')
plt.plot(data)

# %%
data = np.loadtxt('../Data/calogeroSutherland/MC/Interacting/wf_slater_gaussian_nn_sysInfo_bf_stepLength_0.05_numMCSteps_100000_numDims_1_numParticles_2_elementinfo_slater_none_gaussian_none_nn_numhidden1_10_numhidden2_1_activationFunction_sigmoid_.txt')
plt.plot(data)

# %%
data = np.loadtxt('../Data/calogeroSutherland/MC/Interacting/wf_slater_gaussian_nn_sysInfo_is_stepLength_0.05_numMCSteps_100000_numDims_1_numParticles_2_elementinfo_slater_none_gaussian_none_nn_numhidden1_10_numhidden2_1_activationFunction_sigmoid_.txt')
plt.plot(data)

# %%
data = np.loadtxt('../Data/calogeroSutherland/MC/Interacting/wf_slater_gaussian_nn_sysInfo_is_stepLength_0.005_numMCSteps_100000_numDims_1_numParticles_2_elementinfo_slater_none_gaussian_none_nn_numhidden1_10_numhidden2_1_activationFunction_sigmoid_.txt')
plt.plot(data)

# %%
data = np.loadtxt('../Data/calogeroSutherland/MC/Interacting/wf_slater_gaussian_nn_sysInfo_is_stepLength_0.0005_numMCSteps_100000_numDims_1_numParticles_2_elementinfo_slater_none_gaussian_none_nn_numhidden1_10_numhidden2_1_activationFunction_sigmoid_.txt')
plt.plot(data)

# %%
data = np.loadtxt('../Data/calogeroSutherland/MC/Interacting/wf_slater_gaussian_nn_sysInfo_bf_stepLength_0.005_numMCSteps_10000_numDims_1_numParticles_2_elementinfo_slater_none_gaussian_none_nn_numhidden1_10_numhidden2_1_activationFunction_sigmoid_.txt')
plt.plot(data)

# %%
data = np.loadtxt('../Data/calogeroSutherland/MC/Interacting/wf_slater_gaussian_nn_sysInfo_bf_stepLength_0.0005_numMCSteps_100000_numDims_1_numParticles_2_elementinfo_slater_none_gaussian_none_nn_numhidden1_10_numhidden2_1_activationFunction_sigmoid_.txt')
plt.plot(data)
