# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.loadtxt("../Data/QD/VMC/test.txt")
y = np.loadtxt("../Data/QD/VMC/testVP.txt")

# %%
plt.figure(figsize=(20,10))
plt.plot(y)

# %%
plt.figure(figsize=(20,10))
plt.plot(x)
plt.ylim(2.6, 3.4)
# Out:
# (2.6, 3.4)
