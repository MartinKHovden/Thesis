# %%
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# # Sigmoid

# %%
z = np.linspace(-10, 10, 101)

def sigmoid(z):
    return 1/(1+np.exp(-z))

plt.plot(sigmoid(z))

# %% [markdown]
# # ReLu
